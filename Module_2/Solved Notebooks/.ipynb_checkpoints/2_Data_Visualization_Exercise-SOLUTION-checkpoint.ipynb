# %% [markdown]
# # VADSTI 2022
# # Module 4: Data Exploration and Visualization¶
# ## Data Visualization Exercise
#
# The goal of this exercise is to gain hands on experience on generating graphs and visualizaiton data in python using one of the libraries previously discussed (matplotlib, seaborn, plotly). We will be using a dataset that contains information about covid hospitalization rates in the US.
#
#
# #### Dataset Information:
#
# CDC reports aggregate counts of COVID-19 cases and death numbers daily online. Data on the COVID-19 website and CDC’s COVID Data Tracker are based on these most recent numbers reported by states, territories, and other jurisdictions. This data set of “United States COVID-19 Cases and Deaths by State over Time” combines this information. However, data are dependent on jurisdictions’ timely and accurate reporting.

# %% [markdown]
# #### Load the dataset

# %% [markdown]
# Load the dataset into a dataframe called ``df``. The dataset is located``./dataset/covid_deaths_data.csv`` folder

# %%
import pandas as pd
df = pd.read_csv("../datasets/covid_deaths_data.csv")

# %% [markdown]
# #### Display the dataframe's first 5 rows

# %%
df.head(5)
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      12/01/2021    ND     163565    135705.0     27860.0       589
# 1      08/17/2020    MD     100715         NaN         NaN       503
# 2      07/20/2021    MD     464491         NaN         NaN       155
# 3      05/13/2020    VT        855         NaN         NaN         2
# 4      10/06/2021    DE     134690    124148.0     10542.0       444
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0      220.0       1907         NaN         NaN          9         0.0
# 1        0.0       3765      3616.0       149.0          3         0.0
# 2        0.0       9822      9604.0       218.0          3         1.0
# 3        0.0         52         NaN         NaN          0         0.0
# 4       45.0       1977      1810.0       167.0          2         0.0
#
#                created_at consent_cases consent_deaths
# 0  12/02/2021 02:35:20 PM         Agree      Not agree
# 1  08/19/2020 12:00:00 AM           NaN          Agree
# 2  07/22/2021 12:00:00 AM           NaN          Agree
# 3  05/15/2020 12:00:00 AM     Not agree      Not agree
# 4  10/08/2021 12:00:00 AM         Agree          Agree

# %% [markdown]
# #### Check for null values in each columns.

# %%
df.isnull().sum()
# Out:
# submission_date        0
# state                  0
# tot_cases              0
# conf_cases         21441
# prob_cases         21513
# new_case               0
# pnew_case           3702
# tot_death              0
# conf_death         21788
# prob_death         21788
# new_death              0
# pnew_death          3670
# created_at             0
# consent_cases       7945
# consent_deaths      7146
# dtype: int64

# %% [markdown]
# #### Delete all of the rows with null values

# %%
df.dropna(axis=0, inplace=True).reset_index()

# %% [markdown]
# #### Display summary information of the tables. (Hint use ``describe()`` )

# %%
df.describe()

# %% [markdown]
# #### Visualize the total death for any 5 states (e.g. Total deaths for TX, CA, FL, PA, NJ)

# %%
states = df[(df['state']== 'NY') | (df['state']== 'TX') | (df['state']== 'FL') | (df['state']== 'PA') | (df['state']== 'NJ')][['state','tot_death']]

ax = states.groupby('state').sum().plot(figsize=(20, 10), linewidth=2.5, kind = "bar", stacked = 'True', title = "Confirmed Cases in TX, FL, PA, ", grid ="true")

# %% [markdown]
# #### Visualize the percentage of confirmed cases for any 5 states.

# %%
states_conf = df[(df['state']== 'DE') | (df['state']== 'TX') | (df['state']== 'FL') | (df['state']== 'PA') | (df['state']== 'NJ')][['state','conf_cases']]

# states_conf.groupby('state').sum().plot(figsize=(10, 10), linewidth=2.5, kind = "bar", stacked = 'True', title = "Confirmed Cases in TX, FL, PA, ", grid ="true")

states_conf.groupby('state').sum().plot(figsize=(10, 10), kind = "pie", y = 'conf_cases', autopct='%1.0f%%', title='Confirmed Cases in TX, FL, PA')

# %% [markdown]
# #### Based on the visualization types previously discussed, which visualization type will be best to display data from the previous question?

# %%
import plotly.graph_objects as go

# import pandas as pd
df = pd.read_csv('./datasets/covid_deaths_data.csv')

fig = go.Figure(data=go.Choropleth(
    locations=df['state'], # Spatial coordinates
    z = df['tot_death'].astype(float), # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Reds',
    colorbar_title = "Millions USD",
))

fig.update_layout(
    title_text = '2011 US Agriculture Exports by State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()
# Out:
# <div>                            <div id="56c876cd-0f54-446f-a34c-b1471591a350" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56c876cd-0f54-446f-a34c-b1471591a350")) {                    Plotly.newPlot(                        "56c876cd-0f54-446f-a34c-b1471591a350",                        [{"colorbar":{"title":{"text":"Millions USD"}},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"locationmode":"USA-states","locations":["ND","MD","MD","VT","DE","NC","MI","NH","GU","MS","ND","GU","MI","GU","MI","CT","WI","NE","WA","MD","ND","CT","IN","MD","VT","MO","WA","WA","ID","ND","DE","WI","VT","WA","MO","WI","ID","MD","MO","GU","MS","VT","CT","IL","WI","MT","ME","MS","ME","VI","AL","MS","NE","ND","WI","AL","NC","MO","MD","MS","MD","AL","AL","NC","CT","GU","IN","VT","MI","IN","AL","DE","AL","VT","ND","NC","CT","NC","WI","NH","MD","GU","IN","NC","DE","VI","VI","AL","IN","IL","DE","NC","NE","NV","NC","NH","ND","MD","MI","WA","VT","VT","MD","CA","WI","NE","NC","WA","MI","GU","MS","IL","GU","IN","MI","AL","VI","CT","MO","IN","ND","CT","VI","MO","IL","ME","MD","MO","ND","IN","VI","ME","IL","NC","ID","AL","IL","MO","NH","NE","VT","NC","ND","DE","NC","CT","NC","NV","MI","MI","AL","MS","NE","NH","ND","NE","IN","NV","MT","MS","VI","DE","ID","ID","NH","CT","ND","NC","DE","WI","IN","MS","DE","MI","MT","MT","AL","GU","NC","MD","ND","NV","NC","ID","IN","WA","WI","NV","DE","NH","IN","IN","NH","IN","NH","MS","NC","WA","MS","MI","MS","NH","WI","NV","WA","GU","IL","MT","IN","WI","CA","CT","CT","CA","ID","ND","CA","MD","VT","NC","MT","WI","IL","WI","ME","MS","VI","AL","IL","IL","ND","VI","WI","IN","MO","WA","WI","ND","ND","NH","ID","DE","NH","NV","NH","VI","MT","AL","IN","WI","WI","ND","NC","GU","NC","VT","ID","AL","CT","NV","VT","MD","NV","NE","MO","MI","DE","ND","WA","NE","ME","NV","WA","MT","NH","VI","MS","ID","IN","IN","DE","ND","ND","VI","MI","CA","MI","CT","IN","DE","ID","AL","ID","GU","WI","MI","MD","NC","GU","MO","CA","NE","WA","IL","ND","MS","GU","IL","IN","AL","GU","CT","AL","NE","ME","NE","ME","WA","NV","MT","CA","IL","MT","NC","IN","WI","WI","ME","ND","MO","AL","CA","WI","NC","MD","NC","DE","NC","AL","WA","VT","ND","CT","IL","DE","WA","GU","NV","VT","NE","MT","MT","ND","NC","ND","ME","WA","MD","IL","NH","IN","CA","WI","GU","DE","AL","MS","MO","MT","VT","MT","CA","CA","NH","AL","VI","VI","ID","CA","IL","ND","NE","IN","MT","VT","NV","CT","MO","ND","IN","GU","IN","WI","IN","WI","ID","MO","IL","DE","NC","DE","VT","ME","CA","AL","ID","ME","VI","WI","MO","IN","MI","CA","MS","ME","VI","ID","IL","NV","GU","GU","MS","ND","MI","MT","CT","AL","IL","GU","ID","IL","NV","VT","VI","CT","NV","GU","MS","CT","CA","IN","MS","ND","MI","MO","CT","ME","MD","NE","NV","MI","NC","ND","NV","NC","ME","NH","CA","MT","ID","WA","WI","CA","MS","VT","MT","AL","ID","NH","CT","WI","NE","ID","DE","NE","IN","MT","NV","ME","MO","VT","NV","MO","MD","NV","MD","NH","ME","VT","NV","WA","CT","DE","DE","IN","MI","CT","NH","AL","ME","WA","NV","WI","NH","VT","MT","CA","NE","MS","NV","CT","ID","MT","CA","CA","MT","GU","AL","NV","MI","GU","VI","VI","MI","NE","NV","CT","IN","WI","GU","DE","IN","MI","NC","MS","GU","VI","VI","CA","MI","NE","GU","CT","ND","IN","MD","CA","WI","WA","MS","MI","IL","NV","VT","MI","DE","VT","WI","NE","MS","MO","NV","ME","MS","AL","MS","VI","MS","ME","ME","CA","NC","MT","VI","WI","MI","ID","NC","NH","CA","WI","CA","WI","VT","MI","NE","MI","NE","MT","NH","AL","MI","MD","VI","VT","GU","NE","NC","NH","NE","MO","WI","AL","NE","MD","ID","ID","CA","MS","MD","WI","MD","WA","MT","WI","NC","AL","WA","WA","MT","ND","MT","IN","MT","MD","ME","NV","MT","D ...

# %% [markdown]
# #### Generate a corellation heathmap. Explain which features (columns) are highly corellated.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

corr=df.corr()
corr

plt.figure(figsize=(12,10))

plot = sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")

# %% [markdown]
# #### Save figures to folder ./figures/heat_map.png, ./figures/figures.png

# %%
fig = plot.get_figure()
fig.savefig('../figures/my_figure_1.png')
