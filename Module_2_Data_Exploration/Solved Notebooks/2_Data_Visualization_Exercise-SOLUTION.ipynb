# %% [markdown]
# # VADSTI 2023
# # Module 2: Data Exploration and Visualization¶
# ## Data Visualization Exercise
#
# The goal of this exercise is to gain hands on experience on generating graphs and visualizaiton data in python using one of the libraries previously discussed (matplotlib, seaborn, plotly). We will be using a dataset that contains information about covid hospitalization rates in the US.
#
#
# #### Dataset Information:
#
# CDC reports aggregate counts of COVID-19 cases and death numbers daily online. Data on the COVID-19 website and CDC’s COVID Data Tracker are based on these most recent numbers reported by states, territories, and other jurisdictions. This data set of “United States COVID-19 Cases and Deaths by State over Time” combines this information. However, data are dependent on jurisdictions’ timely and accurate reporting.

# %% [markdown]
# #### Load the dataset

# %% [markdown]
# Load the dataset into a dataframe called ``df``. The dataset is located``./dataset/covid_deaths_data.csv`` folder

# %%
import pandas as pd
df = pd.read_csv("../datasets/covid_deaths_data.csv")

# %% [markdown]
# #### Display the dataframe's first 5 rows

# %%
df.head(5)
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      12/01/2021    ND     163565    135705.0     27860.0       589
# 1      08/17/2020    MD     100715         NaN         NaN       503
# 2      07/20/2021    MD     464491         NaN         NaN       155
# 3      05/13/2020    VT        855         NaN         NaN         2
# 4      10/06/2021    DE     134690    124148.0     10542.0       444
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0      220.0       1907         NaN         NaN          9         0.0
# 1        0.0       3765      3616.0       149.0          3         0.0
# 2        0.0       9822      9604.0       218.0          3         1.0
# 3        0.0         52         NaN         NaN          0         0.0
# 4       45.0       1977      1810.0       167.0          2         0.0
#
#                created_at consent_cases consent_deaths
# 0  12/02/2021 02:35:20 PM         Agree      Not agree
# ...

# %% [markdown]
# #### Check for null values in each columns.

# %%
df.isnull().sum()
# Out:
# submission_date        0
# state                  0
# tot_cases              0
# conf_cases         21441
# prob_cases         21513
# new_case               0
# pnew_case           3702
# tot_death              0
# conf_death         21788
# prob_death         21788
# new_death              0
# pnew_death          3670
# created_at             0
# consent_cases       7945
# consent_deaths      7146
# dtype: int64

# %% [markdown]
# #### Delete all of the rows with null values without saving into a new dataframe.

# %%
df.dropna(axis=0, inplace=True)

# %%
df = df.reset_index()

df
# Out:
#        level_0  index submission_date state  tot_cases  conf_cases  \
# 0            0      4      10/06/2021    DE     134690    124148.0
# 1            1      5      02/20/2022    NC    2588707   2166377.0
# 2            2      6      04/28/2020    MI      51401     48887.0
# 3            3      9      12/25/2021    MS     525502    299857.0
# 4            4     12      05/16/2020    MI      81494     75840.0
# ...        ...    ...             ...   ...        ...         ...
# 21586    21586  47632      03/18/2022    NJ    2186846   1888440.0
# 21587    21587  47633      12/11/2020    AZ     394804    380243.0
# 21588    21588  47635      02/10/2021   FSM          1         1.0
# 21589    21589  47637      01/12/2022    WY     123743     97745.0
# 21590    21590  47639      11/22/2021    AZ    1245127   1127692.0
#
#        prob_cases  new_case  pnew_case  tot_death  conf_death  prob_death  \
# 0         10542.0       444       45.0       1977      1810.0       167.0
# ...

# %%
df[df['state']== 'NY']
# Out:
# Empty DataFrame
# Columns: [level_0, index, submission_date, state, tot_cases, conf_cases, prob_cases, new_case, pnew_case, tot_death, conf_death, prob_death, new_death, pnew_death, created_at, consent_cases, consent_deaths]
# Index: []

# %% [markdown]
# #### Display summary information of the tables. (Hint use ``describe()`` )

# %%
df.describe()
# Out:
#             level_0         index     tot_cases    conf_cases     prob_cases  \
# count  21591.000000  21591.000000  2.159100e+04  2.159100e+04   21591.000000
# mean   10795.000000  23781.119679  5.113135e+05  4.461630e+05   65150.533695
# std     6232.929167  14238.674890  6.840016e+05  6.235502e+05  102084.772270
# min        0.000000      4.000000  0.000000e+00  0.000000e+00       0.000000
# 25%     5397.500000  11059.500000  4.130700e+04  3.789150e+04       9.000000
# 50%    10795.000000  23852.000000  2.383480e+05  2.077230e+05   12267.000000
# 75%    16192.500000  36797.500000  7.635625e+05  6.568885e+05   98972.000000
# max    21590.000000  47639.000000  4.885289e+06  4.640489e+06  601422.000000
#
#             new_case     pnew_case     tot_death    conf_death    prob_death  \
# count   21591.000000  21591.000000  21591.000000  21591.000000  21591.000000
# mean     1890.615534    291.677134   8736.960493   7818.153860    918.806632
# ...

# %%
states[states['state']=='NY']
# Out:
# Empty DataFrame
# Columns: [state, tot_death]
# Index: []

# %% [markdown]
# #### Visualize the total death for any 5 states (e.g. Total deaths for WY, DE, NC, AZ, NJ)

# %%
states = df[(df['state']== 'WY') | (df['state']== 'DE') | (df['state']== 'NC') | (df['state']== 'AZ') | (df['state']== 'NJ')][['state','conf_cases']]

ax = states.groupby('state').sum().plot(figsize=(20, 10), linewidth=2.5, kind = "bar", stacked = 'True', title = "Confirmed Cases in WY, DE, NC, and NJ, ", grid ="true")

# %% [markdown]
# #### Visualize the percentage of confirmed cases for any 5 states.

# %%
states_conf = df[(df['state']== 'WY') | (df['state']== 'DE') | (df['state']== 'NC') | (df['state']== 'AZ') | (df['state']== 'NJ')][['state','conf_cases']]

# states_conf.groupby('state').sum().plot(figsize=(10, 10), linewidth=2.5, kind = "bar", stacked = 'True', title = "Confirmed Cases in TX, FL, PA, ", grid ="true")

states_conf.groupby('state').sum().plot(figsize=(10, 10), kind = "pie", y = 'conf_cases', autopct='%1.0f%%', title='Confirmed Cases in TX, FL, PA')

# %% [markdown]
# #### Generate a corellation heathmap. Explain which features (columns) are highly corellated.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

corr=df.corr()
corr

plt.figure(figsize=(12,10))

plot = sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")

# %% [markdown]
# #### Save figures to folder ./figures/heat_map.png, ./figures/figures.png

# %%
fig = plot.get_figure()
fig.savefig('../figures/my_figure_1.png')
